# %%
import requests
import json

# %%
#link da api
url = "https://api.covid19api.com/"
url_summary = "https://api.covid19api.com/summary"
url_country = "https://api.covid19api.com/country/south-africa/status/confirmed"

# %%
payload = {}
headers= {}

response = requests.request("GET", url_summary, headers=headers, data = payload)

response.json()
# Out:
# 379540-eb60-4749-b07a-35b7dc1b2cde',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 194548,
#    'NewDeaths': 0,
#    'TotalDeaths': 2127,
#    'NewRecovered': 0,
#    'TotalRecovered': 173732,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'f7727bf2-6fbf-480a-8210-3f85c1ca3e3c',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 344477,
#    'NewDeaths': 0,
#    'TotalDeaths': 5910,
#    'NewRecovered': 0,
#    'TotalRecovered': 331233,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e81e97c2-9382-4f78-be50-04481a7dc557',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1492,
#    'NewDeaths': 0,
#    'TotalDeaths': 16,
#    'NewRecovered': 0,
#    'TotalRecovered': 846,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '4349cf12-0d64-4ae4-9482-2d3da9047af8',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 166969,
#    'NewDeaths': 0,
#    'TotalDeaths': 3294,
#    'NewRecovered': 0,
#    'TotalRecovered': 139483,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '68ce127c-95e7-40a2-a29e-5569798c2af5',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 8447,
#    'TotalConfirmed': 1358294,
#    'NewDeaths': 185,
#    'TotalDeaths': 47491,
#    'NewRecovered': 14080,
#    'TotalRecovered': 1262722,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'eef80944-0f21-49b5-b4bf-a3f057850365',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 591138,
#    'NewDeaths': 0,
#    'TotalDeaths': 12465,
#    'NewRecovered': 0,
#    'TotalRecovered': 535350,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '6ecb0c24-d93d-4278-93ba-4affd07a9e5d',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1781345,
#    'NewDeaths': 0,
#    'TotalDeaths': 45159,
#    'NewRecovered': 0,
#    'TotalRecovered': 1471608,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '9d2f4b03-845f-428f-a165-be803dcb2c28',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 809412,
#    'NewDeaths': 0,
#    'TotalDeaths': 16512,
#    'NewRecovered': 0,
#    'TotalRecovered': 730601,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '62ee8ae1-de16-452a-a8ab-c1506af02808',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 166475,
#    'NewDeaths': 0,
#    'TotalDeaths': 262,
#    'NewRecovered': 0,
#    'TotalRecovered': 155700,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '0bc3bd50-4eac-44cf-95d6-4a8753be4024',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 72600,
#    'NewDeaths': 0,
#    'TotalDeaths': 1640,
#    'NewRecovered': 0,
#    'TotalRecovered': 61687,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '34c668bf-1e71-4147-9ef7-c11fa9ff16b1',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 824995,
#    'NewDeaths': 0,
#    'TotalDeaths': 20854,
#    'NewRecovered': 0,
#    'TotalRecovered': 754335,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '16824616-8e6b-4dc8-a217-cdd49d7b1c49',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 10909,
#    'TotalConfirmed': 4263785,
#    'NewDeaths': 432,
#    'TotalDeaths': 87253,
#    'NewRecovered': 14896,
#    'TotalRecovered': 3856400,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'dac9fb97-5b6e-429d-b901-3fff39d7d5a6',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19509,
#    'NewDeaths': 0,
#    'TotalDeaths': 267,
#    'NewRecovered': 0,
#    'TotalRecovered': 17810,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '76491f7d-5c65-42fd-9d8a-567993776df0',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 41,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 41,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '8f8602ba-4be7-4e00-afc9-66c3f1868e93',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3843,
#    'NewDeaths': 0,
#    'TotalDeaths': 43,
#    'NewRecovered': 0,
#    'TotalRecovered': 3455,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e251a42a-051f-40db-aef5-dca0cd3cc0f3',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1645,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 949,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '19620d1c-2fe7-4a96-b981-2a8d8bb8f135',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'b6e7d4b0-a03c-458d-a15b-072de6a09cac',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3922,
#    'NewDeaths': 0,
#    'TotalDeaths': 76,
#    'NewRecovered': 0,
#    'TotalRecovered': 3426,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '2891e975-e6fe-43cb-956c-0443db2f7e75',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1944,
#    'NewDeaths': 0,
#    'TotalDeaths': 31,
#    'NewRecovered': 0,
#    'TotalRecovered': 1544,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'bc1311fc-f5cf-4a99-afe4-203d20a514b9',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 379474,
#    'NewDeaths': 0,
#    'TotalDeaths': 6524,
#    'NewRecovered': 0,
#    'TotalRecovered': 370300,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '9a74534b-fd62-4da5-a27c-738cb020e1d0',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 35632,
#    'NewDeaths': 0,
#    'TotalDeaths': 907,
#    'NewRecovered': 0,
#    'TotalRecovered': 30369,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '0205e2b8-d618-4ff6-8638-ec38c984df6a',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 482397,
#    'NewDeaths': 0,
#    'TotalDeaths': 4542,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '0f82a4bf-ecd7-4643-9dd7-af6b40394480',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2979,
#    'NewDeaths': 0,
#    'TotalDeaths': 15,
#    'NewRecovered': 0,
#    'TotalRecovered': 2648,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'bad6d4f0-8739-4410-9d21-335b20a26f94',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3918,
#    'NewDeaths': 0,
#    'TotalDeaths': 79,
#    'NewRecovered': 0,
#    'TotalRecovered': 2678,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'afe1d626-17bb-4ed9-827f-92b7cea1b0a8',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 60020,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 59879,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '54cf63fd-e56d-43a2-b1cd-408997eb726c',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 322104,
#    'NewDeaths': 0,
#    'TotalDeaths': 7739,
#    'NewRecovered': 0,
#    'TotalRecovered': 255300,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e3cf279a-efd6-42ee-8b97-a184d17820d7',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 195086,
#    'NewDeaths': 0,
#    'TotalDeaths': 3888,
#    'NewRecovered': 0,
#    'TotalRecovered': 180366,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '82ab55dd-347e-4f44-94df-5e284d16529a',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 14,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '3e612fd1-f87f-4209-9e26-0e8dc6c6d17b',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8041,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 3932,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'd83cc8c7-a20c-49a2-bdd4-b8970b6a2534',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1520206,
#    'NewDeaths': 0,
#    'TotalDeaths': 50647,
#    'NewRecovered': 0,
#    'TotalRecovered': 1439515,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e56f9f66-361c-49bd-9666-405291967a0b',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8677,
#    'NewDeaths': 0,
#    'TotalDeaths': 102,
#    'NewRecovered': 0,
#    'TotalRecovered': 4317,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '34f8f064-7801-4e2f-83ba-589cfedbaae0',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3149012,
#    'NewDeaths': 0,
#    'TotalDeaths': 71138,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'afee4a60-11b9-4dda-9cbc-38515ebe0271',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85150,
#    'NewDeaths': 0,
#    'TotalDeaths': 493,
#    'NewRecovered': 0,
#    'TotalRecovered': 81769,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'cfa86c48-2f66-48fd-9918-6c30a7735151',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30479,
#    'NewDeaths': 0,
#    'TotalDeaths': 1895,
#    'NewRecovered': 0,
#    'TotalRecovered': 23156,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'cb63ed22-c3fa-4830-aa3f-d4a3e994b1c6',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8971,
#    'NewDeaths': 0,
#    'TotalDeaths': 175,
#    'NewRecovered': 0,
#    'TotalRecovered': 8464,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '11d78380-db17-4b20-a358-884d75de4a2a',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17173,
#    'NewDeaths': 0,
#    'TotalDeaths': 658,
#    'NewRecovered': 0,
#    'TotalRecovered': 15211,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '2992c2f3-ea08-4d4f-bccf-38c3717f7483',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 684961,
#    'NewDeaths': 0,
#    'TotalDeaths': 13003,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'a539bcc5-9f11-4d58-a9bb-b629e10638b0',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 562290,
#    'NewDeaths': 0,
#    'TotalDeaths': 10046,
#    'NewRecovered': 0,
#    'TotalRecovered': 317600,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '527cc78c-0d86-4b06-a408-9c7c753adf30',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15925,
#    'NewDeaths': 0,
#    'TotalDeaths': 1058,
#    'NewRecovered': 0,
#    'TotalRecovered': 10293,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'fef17cf2-89fc-4481-aaa9-3d166cd74c12',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 967,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 932,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '236ea44b-3152-4436-9474-29e5be9e60cd',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13308,
#    'NewDeaths': 0,
#    'TotalDeaths': 90,
#    'NewRecovered': 0,
#    'TotalRecovered': 13218,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '1457affa-ffec-4456-81c5-5269f1a15bde',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '38e5b1b5-f8d9-4ca8-aeec-df2406822202',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26305,
#    'NewDeaths': 0,
#    'TotalDeaths': 85,
#    'NewRecovered': 0,
#    'TotalRecovered': 25686,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e68e8e6f-ee48-46fe-898b-1391a7d73f12',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 119,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 94,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e880c6a4-6129-43ef-9738-f0ffb09f34c3',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7521,
#    'NewDeaths': 0,
#    'TotalDeaths': 90,
#    'NewRecovered': 0,
#    'TotalRecovered': 6258,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '917e87cd-1dd6-4562-a767-8d7d3ef5abd6',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7732,
#    'NewDeaths': 0,
#    'TotalDeaths': 139,
#    'NewRecovered': 0,
#    'TotalRecovered': 7497,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '1f90ac08-f234-4ea9-8f7a-dcb2090f7ebc',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 237028,
#    'NewDeaths': 0,
#    'TotalDeaths': 8167,
#    'NewRecovered': 0,
#    'TotalRecovered': 202123,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '6fa15056-8fe4-4ef3-8a9d-4fb810574e64',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2769230,
#    'NewDeaths': 0,
#    'TotalDeaths': 28965,
#    'NewRecovered': 0,
#    'TotalRecovered': 2616139,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '9e965bda-1525-4885-bb3f-be2322ca0f0b',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 40452,
#    'NewDeaths': 0,
#    'TotalDeaths': 334,
#    'NewRecovered': 0,
#    'TotalRecovered': 15065,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'e5efd5a8-051c-4798-a7be-0010abd0cd1c',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 9257,
#    'TotalConfirmed': 1442457,
#    'NewDeaths': 165,
#    'TotalDeaths': 28392,
#    'NewRecovered': 3482,
#    'TotalRecovered': 1238321,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '1537ef44-e3a0-4e17-b468-0e82cef6a927',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 408236,
#    'NewDeaths': 0,
#    'TotalDeaths': 1310,
#    'NewRecovered': 0,
#    'TotalRecovered': 391205,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '60f543df-249e-4e06-a722-69cf9aa582c2',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 6118,
#    'TotalConfirmed': 4225906,
#    'NewDeaths': 159,
#    'TotalDeaths': 124654,
#    'NewRecovered': 15,
#    'TotalRecovered': 11849,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '6afc15ff-d820-4e46-8cad-9d846b55e202',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 57596,
#    'TotalConfirmed': 28952137,
#    'NewDeaths': 1442,
#    'TotalDeaths': 524319,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '0f63bf16-fcb0-4594-9780-b420cd0921db',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63010,
#    'NewDeaths': 0,
#    'TotalDeaths': 645,
#    'NewRecovered': 0,
#    'TotalRecovered': 54175,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '7864f27c-3bb1-40fd-aa7f-18e0c74b446f',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 80125,
#    'NewDeaths': 0,
#    'TotalDeaths': 622,
#    'NewRecovered': 0,
#    'TotalRecovered': 78802,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '0c5ea2fb-047b-4f22-a6f5-526072727aa9',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '14f234a3-5773-4fc3-b526-cf917d58b942',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 141885,
#    'NewDeaths': 0,
#    'TotalDeaths': 1378,
#    'NewRecovered': 0,
#    'TotalRecovered': 133934,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '5057a69d-fe7e-472a-838d-1ebb8433d449',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2501,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 0,
#    'TotalRecovered': 1920,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '4bc42610-18f2-4f10-b6bf-abf276664de8',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2444,
#    'NewDeaths': 0,
#    'TotalDeaths': 650,
#    'NewRecovered': 0,
#    'TotalRecovered': 1442,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': '37efece0-96a7-4906-a978-2c81258f3e7b',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 82011,
#    'NewDeaths': 0,
#    'TotalDeaths': 1116,
#    'NewRecovered': 0,
#    'TotalRecovered': 77609,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}},
#   {'ID': 'ba6862c6-74ee-4113-b5bf-8ce3f42dc2f0',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36260,
#    'NewDeaths': 0,
#    'TotalDeaths': 1485,
#    'NewRecovered': 0,
#    'TotalRecovered': 33805,
#    'Date': '2021-03-07T07:13:12.389Z',
#    'Premium': {}}],
#  'Date': '2021-03-07T07:13:12.389Z'}

# %%
response[""]

# %%
retorno_api.content
# Out:
# 2": "LR"\n    },\n    {\n        "Country": "Lithuania",\n        "Slug": "lithuania",\n        "ISO2": "LT"\n    },\n    {\n        "Country": "R\xc3\xa9union",\n        "Slug": "r\xc3\xa9union",\n        "ISO2": "RE"\n    },\n    {\n        "Country": "Bulgaria",\n        "Slug": "bulgaria",\n        "ISO2": "BG"\n    },\n    {\n        "Country": "Georgia",\n        "Slug": "georgia",\n        "ISO2": "GE"\n    },\n    {\n        "Country": "Nepal",\n        "Slug": "nepal",\n        "ISO2": "NP"\n    },\n    {\n        "Country": "Sierra Leone",\n        "Slug": "sierra-leone",\n        "ISO2": "SL"\n    },\n    {\n        "Country": "British Indian Ocean Territory",\n        "Slug": "british-indian-ocean-territory",\n        "ISO2": "IO"\n    },\n    {\n        "Country": "Chile",\n        "Slug": "chile",\n        "ISO2": "CL"\n    },\n    {\n        "Country": "Morocco",\n        "Slug": "morocco",\n        "ISO2": "MA"\n    },\n    {\n        "Country": "Cayman Islands",\n        "Slug": "cayman-islands",\n        "ISO2": "KY"\n    },\n    {\n        "Country": "Kiribati",\n        "Slug": "kiribati",\n        "ISO2": "KI"\n    },\n    {\n        "Country": "Uruguay",\n        "Slug": "uruguay",\n        "ISO2": "UY"\n    },\n    {\n        "Country": "Madagascar",\n        "Slug": "madagascar",\n        "ISO2": "MG"\n    },\n    {\n        "Country": "Palestinian Territory",\n        "Slug": "palestine",\n        "ISO2": "PS"\n    },\n    {\n        "Country": "Swaziland",\n        "Slug": "swaziland",\n        "ISO2": "SZ"\n    },\n    {\n        "Country": "Guinea",\n        "Slug": "guinea",\n        "ISO2": "GN"\n    },\n    {\n        "Country": "Italy",\n        "Slug": "italy",\n        "ISO2": "IT"\n    },\n    {\n        "Country": "Norway",\n        "Slug": "norway",\n        "ISO2": "NO"\n    },\n    {\n        "Country": "Pitcairn",\n        "Slug": "pitcairn",\n        "ISO2": "PN"\n    },\n    {\n        "Country": "Dominica",\n        "Slug": "dominica",\n        "ISO2": "DM"\n    },\n    {\n        "Country": "Senegal",\n        "Slug": "senegal",\n        "ISO2": "SN"\n    },\n    {\n        "Country": "American Samoa",\n        "Slug": "american-samoa",\n        "ISO2": "AS"\n    },\n    {\n        "Country": "Croatia",\n        "Slug": "croatia",\n        "ISO2": "HR"\n    },\n    {\n        "Country": "Guatemala",\n        "Slug": "guatemala",\n        "ISO2": "GT"\n    },\n    {\n        "Country": "Pakistan",\n        "Slug": "pakistan",\n        "ISO2": "PK"\n    },\n    {\n        "Country": "Romania",\n        "Slug": "romania",\n        "ISO2": "RO"\n    },\n    {\n        "Country": "Turkey",\n        "Slug": "turkey",\n        "ISO2": "TR"\n    },\n    {\n        "Country": "Benin",\n        "Slug": "benin",\n        "ISO2": "BJ"\n    },\n    {\n        "Country": "Cocos (Keeling) Islands",\n        "Slug": "cocos-keeling-islands",\n        "ISO2": "CC"\n    },\n    {\n        "Country": "Finland",\n        "Slug": "finland",\n        "ISO2": "FI"\n    },\n    {\n        "Country": "Mayotte",\n        "Slug": "mayotte",\n        "ISO2": "YT"\n    },\n    {\n        "Country": "Uzbekistan",\n        "Slug": "uzbekistan",\n        "ISO2": "UZ"\n    },\n    {\n        "Country": "Barbados",\n        "Slug": "barbados",\n        "ISO2": "BB"\n    },\n    {\n        "Country": "Hong Kong, SAR China",\n        "Slug": "hong-kong-sar-china",\n        "ISO2": "HK"\n    },\n    {\n        "Country": "Niue",\n        "Slug": "niue",\n        "ISO2": "NU"\n    },\n    {\n        "Country": "US Minor Outlying Islands",\n        "Slug": "us-minor-outlying-islands",\n        "ISO2": "UM"\n    },\n    {\n        "Country": "Albania",\n        "Slug": "albania",\n        "ISO2": "AL"\n    },\n    {\n        "Country": "Algeria",\n        "Slug": "algeria",\n        "ISO2": "DZ"\n    },\n    {\n        "Country": "Slovenia",\n        "Slug": "slovenia",\n        "ISO2": "SI"\n    },\n    {\n        "Country ...
